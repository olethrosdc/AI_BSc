# %%
from gridworld import GridWorld
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Testing")
np.random.seed(31415)
height = 8
width = 8
environment = GridWorld(width, height, 0.3, 0.5)
environment.render()

from ValueIteration import value_iteration
print("Calculating optimal policy")
policy, V, Q = value_iteration(environment, 100, 1)

print("Policy, ", policy)
policy_string="^v<>"
for y in range(height):
    for x in range(width):
        s = environment.get_state(x,y)
        print(policy_string[policy[s]], end="")
    print("")

print("Values")
Vxy = np.zeros([height, width])
for y in range(height):
    for x in range(width):
        print(V[environment.get_state(x,y)], end=" ")
        Vxy[x,y] = V[environment.get_state(x,y)]
    print("")
plt.matshow(environment.maze.transpose())
plt.matshow(Vxy.transpose())
# Out:
# Testing
# ...#....
# ....#.#.
# ....###.
# ..#.#..#
# .#.....#
# .#..#X..
# .##.....
# ...##O..
# Calculating optimal policy
# Policy,  [3 3 1 1 0 0 0 0 3 3 3 1 2 0 0 0 3 3 3 1 2 1 1 0 3 0 1 1 3 1 1 2 0 3 3 3 3
#  1 2 2 0 3 0 0 3 0 2 2 0 2 0 0 2 0 0 0 0 2 2 0 0 0 0 0 0]
# >>vv^^^^
# >>>v<^^^
# >>>v<vv^
# >^vv>vv<
# ^>>>>v<<
# ^>^^>^<<
# ^<^^<^^^
# ^<<^^^^^
# Values
# -27.984699368827133 -26.30828320285976 -24.33345298178689 -34.53945433784184 -100.0 -100.0 -100.0 -100.0
# -26.692376319658532 -24.532841503783203 -21.840069108308516 -19.05933013206464 -46.92836495107025 -100.0 -100.0 -100.0
# -26.03998928882919 -23.370327894679637 -19.7778079495221 -16.36429557104046 -18.364171989172387 -25.467367396880945 -26.608111581395992 -100.0
# -28.068049567063674 -25.909511670067698 -16.578465644309404 -12.837256960562208 -7.944557409355375 -5.234211537146225 -6.660141975349969 -26.608111581395992
# -30.73268387234647 -19.027711916767522 -12.38129882135835 -9.955541009583023 -5.8932878028339015 -2.8777313129327045 -5.016627185688886 -6.9791779791318636
# -33.39476449512408 -19.54623611401355 -14.08444417365338 -12.897164310686428 -5.797770992878772 1.0 -3.928704332568439 -6.829390642955376
# -36.04823153300626 -38.669482149761606 -20.49520773767164 -15.476499466936726 -17.79399399930125 -19.064126257621286 -11.654916378472038 -10.432141615374622
# -38.669482149761606 -41.16486886295445 -43.16047976797605 -22.61243123739154 -35.8351656018335 -100.0 -28.373339174199074 -15.620379066994218
