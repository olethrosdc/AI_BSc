# %%
from gridworld import GridWorld
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Testing")
np.random.seed(2134)
height = 8
width = 8
environment = GridWorld(width, height, 0.3, 0.3)
environment.render()

from ValueIteration import value_iteration
print("Calculating optimal policy")
policy, V, Q = value_iteration(environment, 100, .9)

print("Policy, ", policy)
policy_string="^v<>"
for y in range(height):
    for x in range(width):
        s = environment.get_state(x,y)
        print(policy_string[policy[s]], end="")
    print("")

print("Values")
Vxy = np.zeros([height, width])
for y in range(height):
    for x in range(width):
        print(V[environment.get_state(x,y)], end=" ")
        Vxy[x,y] = V[environment.get_state(x,y)]
    print("")
plt.matshow(environment.maze.transpose())
plt.matshow(Vxy.transpose())
# Out:
# Testing
# #..#....
# ....#.#.
# ##..#.#.
# ##......
# #X....#.
# ........
# #...O#.#
# .#..#..#
# Calculating optimal policy
# Policy,  [3 3 1 1 3 1 2 1 3 3 1 1 2 1 2 1 0 3 1 1 2 1 2 1 0 1 1 2 2 2 2 2 3 0 2 2 2
#  2 2 0 3 0 2 2 2 0 2 2 0 0 0 2 0 0 0 0 0 0 0 2 2 3 0 2 0]
# >>vv>v<v
# >>vv<v<v
# ^>vv<v<v
# ^vv<<<<<
# >^<<<<<^
# >^<<<^<<
# ^^^<^^^^
# ^^^<<>^<
# Values
# -6.524335646936343 -6.016980824861991 -5.4408817511467635 -5.881771293285746 -7.501473878925832 -7.104882431136282 -7.52996411202162 -7.838080706983472
# -6.110514944721166 -5.493136364518177 -4.655487287081524 -5.101782799463921 -5.968890913680644 -6.557303553244334 -7.106947035909352 -7.527931406758508
# -6.64332111667717 -4.551237665250531 -3.585437037194162 -4.3721053820547215 -5.147827774256766 -5.952174634302631 -6.510142291959835 -7.102309284394487
# -9.999734386011104 -0.6644031167048258 -2.368318304771831 -3.4848949468300225 -4.395153277365939 -5.244827430178343 -5.955513870192171 -6.596756006902228
# -0.6436454376123248 1.0 -0.906901467787304 -2.4568006874347836 -3.7377469167642334 -4.712385775516499 -5.643069359285542 -7.034286385966402
# -2.1230701703085795 -0.8727638481353384 -2.22207535907725 -3.4383761560640322 -4.783787862654362 -5.443070914418768 -6.171075876558076 -6.724253458663724
# -3.6567270518496775 -2.2304439281875488 -3.3916712356193672 -4.705756476741117 -10.0 -6.511805239030772 -6.74013109154238 -7.136349250955808
# -9.999734386011104 -3.9014934402598493 -4.364924795017892 -5.100365119800999 -6.244387151569815 -7.6024423797520075 -7.221877678125342 -7.6024423797520075
