# %%
from gridworld import GridWorld
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Testing")
np.random.seed(2134)
height = 8
width = 8
environment = GridWorld(width, height, 0.3, 0.3)
environment.render()

from ValueIteration import value_iteration
print("Calculating optimal policy")
policy, V, Q = value_iteration(environment, 100, .9)

print("Policy, ", policy)
policy_string="^v<>"
for y in range(height):
    for x in range(width):
        s = environment.get_state(x,y)
        print(policy_string[policy[s]], end="")
    print("")

print("Values")
Vxy = np.zeros([height, width])
for y in range(height):
    for x in range(width):
        print(V[environment.get_state(x,y)], end=" ")
        Vxy[x,y] = V[environment.get_state(x,y)]
    print("")
plt.matshow(environment.maze.transpose())
plt.matshow(Vxy.transpose())
# Out:
# Testing
# #..#....
# ....#.#.
# ##..#.#.
# ##......
# #X....#.
# ........
# #...O#.#
# .#..#..#
# Calculating optimal policy
# Policy,  [3 3 1 1 3 1 2 2 3 3 1 1 2 1 2 1 0 3 1 1 2 1 2 1 0 1 1 2 2 2 2 2 3 0 2 2 2
#  2 2 0 3 0 2 2 0 0 2 2 0 0 2 2 0 0 0 0 0 0 0 2 2 3 0 2 0]
# >>vv>v<<
# >>vv<v<v
# ^>vv<v<v
# ^vv<<<<<
# >^<<<<<^
# >^<<^^<<
# ^^<<^^^^
# ^^^<<>^<
# Values
# -6.534634644511123 -6.028783202956669 -5.454391210927219 -5.904048318569828 -7.561708040629864 -7.174677570888573 -7.589666205499104 -7.8920285811219975
# -6.122040164961766 -5.506490984796967 -4.671324007166479 -5.124468406480632 -5.996589013159516 -6.640283074928428 -7.176975595440991 -7.591156799709005
# -6.653267539624537 -4.566691677125657 -3.6035690016411377 -4.399125688388201 -5.181815616319978 -6.049738120984831 -6.594635937919396 -7.1765644738765015
# -9.999734386011104 -0.6661216075194326 -2.38862195550737 -3.5176209450913873 -4.480948166899814 -5.359439752266244 -6.053436564343259 -6.683979498311354
# -0.6447965399712916 1.0 -0.929329635094333 -2.606588356979774 -4.417137565671011 -5.299495297507322 -6.1208426303924455 -7.16383894098376
# -2.136670231512668 -0.888522649213092 -2.3618250167790094 -4.586218863670339 -12.098521203607088 -6.511179002861109 -7.064261019285455 -7.44080698516143
# -3.6716542362860203 -2.294799127874371 -4.004933858897227 -11.7941397698104 -100.0 -13.843697545845481 -7.500570938978137 -7.766767321671129
# -9.999734386011104 -3.9931247719419485 -4.9385148113485275 -6.153440458447366 -14.078131953918184 -8.16172816766501 -7.869938987929298 -8.16172816766501
